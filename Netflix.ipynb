# %%
import pandas as pd
data = pd.read_csv("C:/Notes/DataSets/8. Netflix Dataset.csv")
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.isnull().count
# Out:
# <bound method DataFrame.count of       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# ...

# %%
(data["Country"]=="Brazil").sum()
# Out:
# 72

# %%
Brazil_data=data[data["Country"]=="Brazil"]
Brazil_data[Brazil_data["Duration"] == "4 Seasons"]
# Out:
#   Show_Id Category Title Director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 Cast Country     Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          Description
# 0  In a future where the elite inhabit an island ...

# %%
data[data["Director"]=="Shane Acker"]
# Out:
#   Show_Id Category Title     Director  \
# 3      s4    Movie     9  Shane Acker
#
#                                                 Cast        Country  \
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description
# 3  In a postapocalyptic world, rag-doll robots hi...

# %%
data[data["Director"]=="Carla Barros"]
# Out:
#     Show_Id Category            Title      Director  \
# 218    s219  TV Show  A Queen Is Born  Carla Barros
#
#                               Cast Country       Release_Date Rating  \
# 218  Gloria Groove, Alexia Twister  Brazil  November 11, 2020  TV-14
#
#      Duration                                Type  \
# 218  1 Season  International TV Shows, Reality TV
#
#                                            Description
# 218  Gloria Groove and Alexia Twister make drag dre...

# %%
data[data.Release_Date == "July 2, 2020"]
# Out:
#      Show_Id Category                  Title                       Director  \
# 5912   s5912  TV Show      Supermarket Sweep                            NaN
# 7046   s7045    Movie  Thiago Ventura: POKAS  Fabio Ock, Joana Mazzucchelli
# 7486   s7485  TV Show            Warrior Nun                            NaN
#
#                                                    Cast        Country  \
# 5912                                                NaN  United States
# 7046                                     Thiago Ventura         Brazil
# 7486  Alba Baptista, Toya Turner, Lorena Andrea, Kri...  United States
#
#       Release_Date Rating  Duration  \
# 5912  July 2, 2020   TV-G  1 Season
# 7046  July 2, 2020  TV-MA    82 min
# 7486  July 2, 2020  TV-MA  1 Season
#
#                                                    Type  \
# 5912                                         Reality TV
# 7046                                    Stand-Up Comedy
# ...

# %%
data[data.Release_Date == "July 2, 2020"]
# Out:
#      Show_Id Category                  Title                       Director  \
# 5912   s5912  TV Show      Supermarket Sweep                            NaN
# 7046   s7045    Movie  Thiago Ventura: POKAS  Fabio Ock, Joana Mazzucchelli
# 7486   s7485  TV Show            Warrior Nun                            NaN
#
#                                                    Cast        Country  \
# 5912                                                NaN  United States
# 7046                                     Thiago Ventura         Brazil
# 7486  Alba Baptista, Toya Turner, Lorena Andrea, Kri...  United States
#
#       Release_Date Rating  Duration  \
# 5912  July 2, 2020   TV-G  1 Season
# 7046  July 2, 2020  TV-MA    82 min
# 7486  July 2, 2020  TV-MA  1 Season
#
#                                                    Type  \
# 5912                                         Reality TV
# 7046                                    Stand-Up Comedy
# ...

# %%
data[(data['Release_Date'] == "July 2, 2020") & (data['Rating'] == "TV-G")]
# Out:
#      Show_Id Category              Title Director Cast        Country  \
# 5912   s5912  TV Show  Supermarket Sweep      NaN  NaN  United States
#
#       Release_Date Rating  Duration        Type  \
# 5912  July 2, 2020   TV-G  1 Season  Reality TV
#
#                                             Description
# 5912  In this iconic game show, contestants answer f...

# %%
data.dropna()
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data[data["Country"]=="India"]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
India_data=data[data["Country"]=="India"]
India_data
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...
