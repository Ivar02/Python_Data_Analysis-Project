# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Notes/DataSets/population.csv")
data
# Out:
#       Country Name Country Code  Year     Value
# 0            Aruba          ABW  1960     54608
# 1            Aruba          ABW  1961     55811
# 2            Aruba          ABW  1962     56682
# 3            Aruba          ABW  1963     57475
# 4            Aruba          ABW  1964     58178
# ...            ...          ...   ...       ...
# 16395     Zimbabwe          ZWE  2017  14751101
# 16396     Zimbabwe          ZWE  2018  15052184
# 16397     Zimbabwe          ZWE  2019  15354608
# 16398     Zimbabwe          ZWE  2020  15669666
# 16399     Zimbabwe          ZWE  2021  15993524
#
# [16400 rows x 4 columns]

# %%
data.head()
# Out:
#   Country Name Country Code  Year  Value
# 0        Aruba          ABW  1960  54608
# 1        Aruba          ABW  1961  55811
# 2        Aruba          ABW  1962  56682
# 3        Aruba          ABW  1963  57475
# 4        Aruba          ABW  1964  58178

# %%
data.tail()
# Out:
#       Country Name Country Code  Year     Value
# 16395     Zimbabwe          ZWE  2017  14751101
# 16396     Zimbabwe          ZWE  2018  15052184
# 16397     Zimbabwe          ZWE  2019  15354608
# 16398     Zimbabwe          ZWE  2020  15669666
# 16399     Zimbabwe          ZWE  2021  15993524

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')

# %%
Zimbabwe_data=data[(data["Country Name"] == "Zimbabwe") & (data["Country Code"]== "ZWE")]
Zimbabwe_data
# Out:
#       Country Name Country Code  Year     Value
# 16338     Zimbabwe          ZWE  1960   3806310
# 16339     Zimbabwe          ZWE  1961   3925952
# 16340     Zimbabwe          ZWE  1962   4049778
# 16341     Zimbabwe          ZWE  1963   4177931
# 16342     Zimbabwe          ZWE  1964   4310332
# ...            ...          ...   ...       ...
# 16395     Zimbabwe          ZWE  2017  14751101
# 16396     Zimbabwe          ZWE  2018  15052184
# 16397     Zimbabwe          ZWE  2019  15354608
# 16398     Zimbabwe          ZWE  2020  15669666
# 16399     Zimbabwe          ZWE  2021  15993524
#
# [62 rows x 4 columns]

# %%
Zimbabwe_ZWE_data["Value"].sum()
# Out:
# 592721581

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16400 entries, 0 to 16399
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  16400 non-null  object
#  1   Country Code  16400 non-null  object
#  2   Year          16400 non-null  int64
#  3   Value         16400 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 512.6+ KB

# %%
data.describe()
# Out:
#                Year         Value
# count  16400.000000  1.640000e+04
# mean    1990.529268  2.140804e+08
# std       17.895507  7.040554e+08
# min     1960.000000  2.646000e+03
# 25%     1975.000000  9.863025e+05
# 50%     1991.000000  6.731400e+06
# 75%     2006.000000  4.602445e+07
# max     2021.000000  7.888409e+09

# %%
India_data=data[data["Country Name"] == "India"]
India_data
# Out:
#      Country Name Country Code  Year       Value
# 6758        India          IND  1960   445954579
# 6759        India          IND  1961   456351876
# 6760        India          IND  1962   467024193
# 6761        India          IND  1963   477933619
# 6762        India          IND  1964   489059309
# ...           ...          ...   ...         ...
# 6815        India          IND  2017  1354195680
# 6816        India          IND  2018  1369003306
# 6817        India          IND  2019  1383112050
# 6818        India          IND  2020  1396387127
# 6819        India          IND  2021  1407563842
#
# [62 rows x 4 columns]

# %%
India_data
# Out:
#      Country Name Country Code  Year       Value
# 6758        India          IND  1960   445954579
# 6759        India          IND  1961   456351876
# 6760        India          IND  1962   467024193
# 6761        India          IND  1963   477933619
# 6762        India          IND  1964   489059309
# ...           ...          ...   ...         ...
# 6815        India          IND  2017  1354195680
# 6816        India          IND  2018  1369003306
# 6817        India          IND  2019  1383112050
# 6818        India          IND  2020  1396387127
# 6819        India          IND  2021  1407563842
#
# [62 rows x 4 columns]

# %%
 India_data["Value"].sum()
# Out:
# 55782631401

# %%
sns.barplot(x=India_data["Year"], y=India_data["Value"], palette="Blues_d")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14472\376925570.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=India_data["Year"], y=India_data["Value"], palette="Blues_d")
# <Axes: xlabel='Year', ylabel='Value'>

# %%
import matpolotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import matpolotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matpolotlib'

# %%
India_data.plot(x="Year",y="Value",title = "Value Over Years in India")
plt.show()
