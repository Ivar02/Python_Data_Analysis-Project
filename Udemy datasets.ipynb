# %%
import pandas as pd
data  = pd.read_csv("C:/Notes/DataSets/7. Udemy Courses Data.csv")

# %%
data.tail()
# Out:
#       course_id                                       course_title  is_paid  \
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 3677   120             1566           29            36      All Levels
# 3678    70             1018           12            22  Beginner Level
# 3679    40              723          130            37      All Levels
# 3680  Free              229            0            33      All Levels
# 3681    50               12            1            15      All Levels
#
#      content_duration   published_timestamp              subject
# ...

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data["level"]=="All Levels"
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677     True
# 3678    False
# 3679     True
# 3680     True
# 3681     True
# Name: level, Length: 3682, dtype: bool

# %%
sum(data["level"]=="All Levels")
# Out:
# 1932

# %%
data[data["level"]=="All Levels"]
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 15       145220                  1. Principles of Simple Interest      True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 17       157336                        10.  Bonds and Bond Pricing     True
# ...         ...                                                ...      ...
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
filtered_data = data[data["is_paid"] == False]
filtered_data
# Out:
#       course_id                                       course_title  is_paid  \
# 41       286070        5 lecciones que todo guitarrista debe tomar    False
# 49       696630  7 Ways A Beginner Guitarist Can Sound Better, ...    False
# 57       955914  A beginner`s guide to fingerpicking and strumm...    False
# 67       270976                             A how to guide in HTML    False
# 74      1214144  ¡Triunfar en La Bolsa de Valores No Requiere d...    False
# ...         ...                                                ...      ...
# 3620     552598  WordPress in under an hour - Create/manage you...    False
# 3638    1068590                     Wordpress Website Mastery 2017    False
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
# 3674    1257976  Your First 10 Guitar Lessons - Learn how to pl...    False
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
(data["is_paid"] == "False").count()
# Out:
# 3682

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3682 entries, 0 to 3681
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3682 non-null   int64
#  1   course_title         3682 non-null   object
#  2   is_paid              3682 non-null   bool
#  3   price                3682 non-null   object
#  4   num_subscribers      3682 non-null   int64
#  5   num_reviews          3682 non-null   int64
#  6   num_lectures         3682 non-null   int64
#  7   level                3682 non-null   object
#  8   content_duration     3682 non-null   object
#  9   published_timestamp  3682 non-null   object
#  10  subject              3682 non-null   object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 291.4+ KB

# %%
data.describe()
# Out:
#           course_id  num_subscribers   num_reviews  num_lectures
# count  3.682000e+03      3682.000000   3682.000000   3682.000000
# mean   6.766121e+05      3194.230310    156.093156     40.065182
# std    3.436355e+05      9499.378361    934.957204     50.373299
# min    8.324000e+03         0.000000      0.000000      0.000000
# 25%    4.078430e+05       110.250000      4.000000     15.000000
# 50%    6.885580e+05       911.500000     18.000000     25.000000
# 75%    9.617515e+05      2540.250000     67.000000     45.000000
# max    1.282064e+06    268923.000000  27445.000000    779.000000

# %%
data["subject"]=="Business Finance"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3677    False
# 3678    False
# 3679    False
# 3680     True
# 3681    False
# Name: subject, Length: 3682, dtype: bool

# %%
Business_data=data[(data["subject"]=="Business Finance")]
Business_data
# Out:
#       course_id                                       course_title  is_paid  \
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 9        738910  [Value Investing] Where White People Keep Thei...     True
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 15       145220                  1. Principles of Simple Interest      True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# ...         ...                                                ...      ...
# 3668     425126                     Year-end QuickBooks Procedures     True
# 3669     180384                               Yield Curve Dynamics     True
# 3673      79364                       Your Business by the Numbers     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
#
# ...

# %%
Business_data['hours'] = Content_hours['content_duration'].int.replace(' hours', '').astype(float)
Content_hours
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 Business_data['hours'] = Content_hours['content_duration'].int.replace(' hours', '').astype(float)
#       2 Content_hours
#
# TypeError: string indices must be integers, not 'str'

# %%
Content_hours = (Business_data["content_duration"]).sum()
Content_hours
# Out:
# '5.5 hours4 hours31 mins1 hour1 hour1 hour8.5 hours2 hours1 hour1.5 hours1 hour1.5 hours2 hours1 hour1.5 hours1.5 hours2.5 hours1.5 hours1.5 hours5 hours5.5 hours1 hour1 hour1.5 hours8.5 hours1 hour1 hour1 hour1.5 hours1 hour2 hours1 hour3 hours1 hour1.5 hours3.5 hours3.5 hours3.5 hours1 hour3 hours3 hours14.5 hours2 hours1.5 hours2.5 hours8.5 hours5 hours2 hours24.5 hours33 mins1.5 hours29 hours1 hour1 hour1.5 hours1.5 hours2.5 hours1 hour6 hours1.5 hours13.5 hours1.5 hours1 hour1 hour1.5 hours1.5 hours9 hours3 hours1.5 hours8.5 hours1.5 hours1 hour42 mins2.5 hours33 hours1 hour3.5 hours62 hours4 hours1 hour1.5 hours6.5 hours24.5 hours2 hours32 mins1.5 hours3 hours1 hour2 hours1.5 hours2.5 hours2 hours3 hours1.5 hours39 mins2 hours1.5 hours6.5 hours1 hour19 mins4.5 hours1.5 hours2 hours1.5 hours37 mins10.5 hours1 hour1.5 hours2 hours2 hours3 hours8 hours1 hour2.5 hours2 hours4 hours1.5 hours2 hours1.5 hours14 hours4.5 hours4 hours1 hour2.5 hours1 hour1.5 hours31.5 hours2 hours1.5 ho
# ...

# %%
import math
hours = math
