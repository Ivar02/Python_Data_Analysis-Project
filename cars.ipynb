# %%
import pandas as pd
data = pd.read_csv("C:/Notes/DataSets/2. Cars Data.csv")
print(data)
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data[(data.EngineSize == 3.5) | (data.EngineSize == 2.0)]
# Out:
#            Make                           Model   Type  Origin DriveTrain  \
# 0         Acura                             MDX    SUV    Asia        All
# 1         Acura                  RSX Type S 2dr  Sedan    Asia      Front
# 4         Acura                      3.5 RL 4dr  Sedan    Asia      Front
# 5         Acura         3.5 RL w/Navigation 4dr  Sedan    Asia      Front
# 76    Chevrolet                   Malibu LS 4dr  Sedan     USA      Front
# ..          ...                             ...    ...     ...        ...
# 373      Suzuki                   Forenza S 4dr  Sedan    Asia      Front
# 374      Suzuki                  Forenza EX 4dr  Sedan    Asia      Front
# 406  Volkswagen                    Golf GLS 4dr  Sedan  Europe      Front
# 411  Volkswagen  New Beetle GLS convertible 2dr  Sedan  Europe      Front
# 417  Volkswagen                        Jetta GL  Wagon  Europe      Front
#
#          MSRP   Invoice  EngineSize  Cylinders  Horsepower  MPG_City  \
# ...

# %%
sum((data["Origin"]=="Asia") & (data["MPG_Highway"]== 23.0))
# Out:
# 5

# %%
data[(data["Origin"]=="Asia") | (data["MPG_Highway"]== 23.0)]
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %%
sum(data["EngineSize"]==3.4)
# Out:
# 12

# %%
data[(data["EngineSize"]==3.4)]
# Out:
#            Make                     Model   Type Origin DriveTrain      MSRP  \
# 49        Buick             Rendezvous CX    SUV    USA      Front  $26,545
# 74    Chevrolet                Impala 4dr  Sedan    USA      Front  $21,900
# 77    Chevrolet        Monte Carlo LS 2dr  Sedan    USA      Front  $21,825
# 83    Chevrolet                Venture LS  Sedan    USA      Front  $27,020
# 321  Oldsmobile             Alero GLS 2dr  Sedan    USA      Front  $23,675
# 322  Oldsmobile             Silhouette GL  Sedan    USA      Front  $28,790
# 323     Pontiac                    Aztekt    SUV    USA      Front  $21,595
# 325     Pontiac           Grand Am GT 2dr  Sedan    USA      Front  $22,450
# 330     Pontiac                   Montana  Sedan    USA      Front  $23,845
# 331     Pontiac               Montana EWB  Sedan    USA        All  $31,370
# 402      Toyota     Tundra Regular Cab V6  Truck   Asia       Rear  $16,495
# ...

# %%
data[(data["MPG_City"]== 19) & (data["Horsepower"] == 170)]
# Out:
#         Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 178  Hyundai  Sonata GLS 4dr  Sedan   Asia      Front  $19,339   $17,574
# 179  Hyundai   Sonata LX 4dr  Sedan   Asia      Front  $20,339   $18,380
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 178         2.7        6.0       170.0      19.0         27.0  3217.0
# 179         2.7        6.0       170.0      19.0         27.0  3217.0
#
#      Wheelbase  Length
# 178      106.0   187.0
# 179      106.0   187.0

# %%
data[(data.Make == "Audi") & (data.EngineSize == 2.7)]
# Out:
#     Make                     Model   Type  Origin DriveTrain      MSRP  \
# 16  Audi  A6 2.7 Turbo Quattro 4dr  Sedan  Europe        All  $42,840
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 16  $38,840          2.7        6.0       250.0      18.0         25.0
#
#     Weight  Wheelbase  Length
# 16  3836.0      109.0   192.0

# %%
data[(data.Make == "Audi")]
# Out:
#     Make                             Model    Type  Origin DriveTrain  \
# 7   Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8   Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9   Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10  Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11  Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# 12  Audi                        A6 3.0 4dr   Sedan  Europe      Front
# 13  Audi                A6 3.0 Quattro 4dr   Sedan  Europe        All
# 14  Audi            A4 3.0 convertible 2dr   Sedan  Europe      Front
# 15  Audi    A4 3.0 Quattro convertible 2dr   Sedan  Europe        All
# 16  Audi          A6 2.7 Turbo Quattro 4dr   Sedan  Europe        All
# 17  Audi                A6 4.2 Quattro 4dr   Sedan  Europe        All
# 18  Audi                  A8 L Quattro 4dr   Sedan  Europe        All
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    float64
#  10  MPG_City     428 non-null    float64
#  11  MPG_Highway  428 non-null    float64
#  12  Weight       428 non-null    float64
#  13  Wheelbase    428 non-null    float64
#  14  Length       428 non-null    float64
# dtypes: float64(8), object(7)
# memory usage: 50.8+ KB

# %%
data.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
sum(data["MPG_City"] < 22.0)
# Out:
# 321

# %%
data.isnull()
# Out:
#       Make  Model   Type  Origin  DriveTrain   MSRP  Invoice  EngineSize  \
# 0    False  False  False   False       False  False    False       False
# 1    False  False  False   False       False  False    False       False
# 2    False  False  False   False       False  False    False       False
# 3    False  False  False   False       False  False    False       False
# 4    False  False  False   False       False  False    False       False
# ..     ...    ...    ...     ...         ...    ...      ...         ...
# 427  False  False  False   False       False  False    False       False
# 428  False  False  False   False       False  False    False       False
# 429  False  False  False   False       False  False    False       False
# 430  False  False  False   False       False  False    False       False
# 431  False  False  False   False       False  False    False       False
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
data.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  428.000000  426.000000  428.000000  428.000000   428.000000
# mean     3.196729    5.807512  215.885514   20.060748    26.843458
# std      1.108595    1.558443   71.836032    5.238218     5.741201
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.375000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.250000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   428.000000  428.000000  428.000000
# mean   3577.953271  108.154206  186.362150
# std     758.983215    8.311813   14.357991
# min    1850.000000   89.000000  143.000000
# 25%    3104.000000  103.000000  178.000000
# 50%    3474.500000  107.000000  187.000000
# 75%    3977.750000  112.000000  194.000000
# ...

# %%
Sedan_Engine=data[(data["Type"] == "Sedan") & (data["EngineSize"]== 2.0)]
Sedan_Engine
# Out:
#            Make                           Model   Type  Origin DriveTrain  \
# 1         Acura                  RSX Type S 2dr  Sedan    Asia      Front
# 108       Dodge                     Neon SE 4dr  Sedan     USA      Front
# 109       Dodge                    Neon SXT 4dr  Sedan     USA      Front
# 124        Ford             Focus ZX3 2dr hatch  Sedan     USA      Front
# 125        Ford                    Focus LX 4dr  Sedan     USA      Front
# 126        Ford                    Focus SE 4dr  Sedan     USA      Front
# 127        Ford                   Focus ZX5 5dr  Sedan     USA      Front
# 128        Ford                   Focus SVT 2dr  Sedan     USA      Front
# 163       Honda              Civic Si 2dr hatch  Sedan    Asia      Front
# 175     Hyundai                 Elantra GLS 4dr  Sedan    Asia      Front
# 176     Hyundai                  Elantra GT 4dr  Sedan    Asia      Front
# 177     Hyundai            Elantra GT 4dr hatch  Sedan    Asia      Front
# ...

# %%
Sedan_Engine
# Out:
#            Make                           Model   Type  Origin DriveTrain  \
# 1         Acura                  RSX Type S 2dr  Sedan    Asia      Front
# 108       Dodge                     Neon SE 4dr  Sedan     USA      Front
# 109       Dodge                    Neon SXT 4dr  Sedan     USA      Front
# 124        Ford             Focus ZX3 2dr hatch  Sedan     USA      Front
# 125        Ford                    Focus LX 4dr  Sedan     USA      Front
# 126        Ford                    Focus SE 4dr  Sedan     USA      Front
# 127        Ford                   Focus ZX5 5dr  Sedan     USA      Front
# 128        Ford                   Focus SVT 2dr  Sedan     USA      Front
# 163       Honda              Civic Si 2dr hatch  Sedan    Asia      Front
# 175     Hyundai                 Elantra GLS 4dr  Sedan    Asia      Front
# 176     Hyundai                  Elantra GT 4dr  Sedan    Asia      Front
# 177     Hyundai            Elantra GT 4dr hatch  Sedan    Asia      Front
# ...
